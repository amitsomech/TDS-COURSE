# %% [markdown]
# # Patterns Mining & Association Rules
# Mining frequent patterns and association rules over the [House prices dataset (Kaggle)](https://www.kaggle.com/c/house-prices-advanced-regression-techniques/data) <br>

# %% [markdown]
# ### 0. Imports

# %%
#data processing
import pandas as pd
import numpy as np
import scipy as sp

#statistics
from scipy import stats
import statsmodels.api as sm


#data visualizations
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline


#Machine learning library
import sklearn

#Patterns Mining
from efficient_apriori import apriori

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ##### Loading the CSV dataset

# %%
dataset_path = "../datasets/houseprices/train.csv"
dtf = pd.read_csv(dataset_path,index_col='Id')

# %% [markdown]
# ##### Defining numeric and categorical columns

# %%
numeric_columns = dtf.dtypes[(dtf.dtypes=="float64") | (dtf.dtypes=="int64")].index.tolist()
very_numerical = [nc for nc in numeric_columns if dtf[nc].nunique()>20]
categorical_columns = [c for c in dtf.columns if c not in numeric_columns]
ordinals = list(set(numeric_columns) - set(very_numerical))

# %% [markdown]
# ##### Filling Null Values with the column's mean

# %%
na_columns = dtf[very_numerical].isna().sum()
na_columns = na_columns[na_columns>0]
for nc in na_columns.index:
    dtf[nc].fillna(dtf[nc].mean(),inplace=True)

# %% [markdown]
# ##### Dropping and filling NA values for categorical columns:

# %% [markdown]
# 1. drop if at least 70% are NA:

# %%
nul_cols = dtf[categorical_columns].isna().sum()/len(dtf)
drop_us = nul_cols[nul_cols>0.7]

# %%
dtf=dtf.drop(drop_us.index,axis=1)
categorical_columns = list(set(categorical_columns)-set(drop_us.index))

# %% [markdown]
# 2. Fill with a new 'na' category:

# %%
dtf[categorical_columns]= dtf[categorical_columns].fillna('na')

# %% [markdown]
# ### 1. Basic Apriori Example

# %%
transactions = [('eggs', 'milk', 'soup'),
                ('eggs', 'milk', 'apple'),
                ('soup', 'milk', 'banana')]

# %%
itemsets, rules = apriori(transactions, min_support=0.5, min_confidence=1)
print(rules)  # [{eggs} -> {bacon}, {soup} -> {bacon}]
# Out:
# [{eggs} -> {milk}, {soup} -> {milk}]

# %%
r = rules[0]

# %%
type(r)
# Out:
# efficient_apriori.rules.Rule

# %%
r.confidence,r.lift
# Out:
# (1.0, 1.0)

# %%
r.lhs,r.rhs
# Out:
# (('eggs',), ('milk',))

# %% [markdown]
# ### 2. Using Apriori on a DataFrame:

# %% [markdown]
# We neet to convert our dataframe to a list of transacitons </br>
# *Remember:* We want to keep the column names

# %%
df=dtf.copy()

# %%
records = df[categorical_columns[:5]].to_dict(orient='records')
records[:2]
# Out:
# [{'Condition2': 'Norm',
#   'HouseStyle': '2Story',
#   'BsmtQual': 'Gd',
#   'GarageType': 'Attchd',
#   'Heating': 'GasA'},
#  {'Condition2': 'Norm',
#   'HouseStyle': '1Story',
#   'BsmtQual': 'Gd',
#   'GarageType': 'Attchd',
#   'Heating': 'GasA'}]

# %%
transactions=[]
for r in records:
    transactions.append(list(r.items()))

# %%
transactions[:2]
# Out:
# [[('Condition2', 'Norm'),
#   ('HouseStyle', '2Story'),
#   ('BsmtQual', 'Gd'),
#   ('GarageType', 'Attchd'),
#   ('Heating', 'GasA')],
#  [('Condition2', 'Norm'),
#   ('HouseStyle', '1Story'),
#   ('BsmtQual', 'Gd'),
#   ('GarageType', 'Attchd'),
#   ('Heating', 'GasA')]]

# %%
itemsets, rules = apriori(transactions, min_support=0.1, min_confidence=0.8,output_transaction_ids=False)
#print(rules)  # [{eggs} -> {bacon}, {soup} -> {bacon}]

# %%
len(rules)
# Out:
# 102

# %%
rules[:10]
# Out:
# [{('BsmtQual', 'Gd')} -> {('Condition2', 'Norm')},
#  {('BsmtQual', 'Gd')} -> {('Heating', 'GasA')},
#  {('BsmtQual', 'TA')} -> {('Condition2', 'Norm')},
#  {('BsmtQual', 'TA')} -> {('Heating', 'GasA')},
#  {('GarageType', 'Attchd')} -> {('Condition2', 'Norm')},
#  {('GarageType', 'Detchd')} -> {('Condition2', 'Norm')},
#  {('Heating', 'GasA')} -> {('Condition2', 'Norm')},
#  {('Condition2', 'Norm')} -> {('Heating', 'GasA')},
#  {('HouseStyle', '1.5Fin')} -> {('Condition2', 'Norm')},
#  {('HouseStyle', '1Story')} -> {('Condition2', 'Norm')}]

# %% [markdown]
# ##### What about numerical data? We need to bin....

# %%
binned_price = pd.qcut(dtf.SalePrice,5,labels=["very low", "low", "medium", "high","very high"])

# %%
binned_price.head()
# Out:
# Id
# 1         high
# 2         high
# 3         high
# 4          low
# 5    very high
# Name: SalePrice, dtype: category
# Categories (5, object): ['very low' < 'low' < 'medium' < 'high' < 'very high']

# %% [markdown]
# Binning all numeric columns in the same manner:

# %%
for c in very_numerical:
    try:
        df[c] = pd.qcut(dtf[c],5,labels=["very low", "low", "medium", "high","very high"])
    except:
        #sometimes for highly skewed data, we cannot perform qcut as most quantiles are equal
        df[c] = pd.cut(dtf[c],5,labels=["very low", "low", "medium", "high","very high"])

# %% [markdown]
# Focusing on prominent columns:

# %%
good_columns = ['OverallQual', 'YearBuilt', 'YearRemodAdd', 'OverallQual', 'OverallCond', 'BldgType', 'LotArea', 'GrLivArea', 'FullBath', 'BedroomAbvGr', 'LotFrontage', 'TotalBsmtSF', 'SalePrice']
gdf = df[good_columns]

# %%
gdf.head()
# Out:
#     OverallQual YearBuilt YearRemodAdd  OverallQual  OverallCond BldgType  \
# Id
# 1             7      high         high            7            5     1Fam
# 2             6    medium          low            6            8     1Fam
# 3             7      high         high            7            5     1Fam
# 4             7  very low          low            7            5     1Fam
# 5             8      high         high            8            5     1Fam
#
#       LotArea  GrLivArea  FullBath  BedroomAbvGr LotFrontage TotalBsmtSF  \
# Id
# 1         low       high         2             3         low         low
# 2      medium        low         2             3        high        high
# 3        high       high         2             3         low      medium
# 4      medium       high         1             3         low         low
# 5   very high  very high         2             4   very high        high
#
#     SalePrice
# Id
# 1        high
# 2        high
# 3        high
# 4         low
# 5   very high

# %% [markdown]
# Converting to transactions:

# %%
records = gdf.to_dict(orient='records')
transactions=[]
for r in records:
    transactions.append(list(r.items()))

# %%
transactions[:2]
# Out:
# [[('OverallQual', 7),
#   ('YearBuilt', 'high'),
#   ('YearRemodAdd', 'high'),
#   ('OverallCond', 5),
#   ('BldgType', '1Fam'),
#   ('LotArea', 'low'),
#   ('GrLivArea', 'high'),
#   ('FullBath', 2),
#   ('BedroomAbvGr', 3),
#   ('LotFrontage', 'low'),
#   ('TotalBsmtSF', 'low'),
#   ('SalePrice', 'high')],
#  [('OverallQual', 6),
#   ('YearBuilt', 'medium'),
#   ('YearRemodAdd', 'low'),
#   ('OverallCond', 8),
#   ('BldgType', '1Fam'),
#   ('LotArea', 'medium'),
#   ('GrLivArea', 'low'),
#   ('FullBath', 2),
#   ('BedroomAbvGr', 3),
#   ('LotFrontage', 'high'),
#   ('TotalBsmtSF', 'high'),
#   ('SalePrice', 'high')]]

# %% [markdown]
# Rules mining process:

# %%
itemsets, rules = apriori(transactions, min_support=0.05, min_confidence=0.8)
len(rules)
# Out:
# 1787

# %%
rules[:5]
# Out:
# [{('BedroomAbvGr', 3)} -> {('BldgType', '1Fam')},
#  {('BedroomAbvGr', 4)} -> {('BldgType', '1Fam')},
#  {('FullBath', 1)} -> {('BldgType', '1Fam')},
#  {('GrLivArea', 'high')} -> {('BldgType', '1Fam')},
#  {('GrLivArea', 'medium')} -> {('BldgType', '1Fam')}]

# %% [markdown]
# ### 2. Analyzing the rules:
# We need a better way to see the rules.

# %% [markdown]
# Let's extract all the rules attributes for all rules and put them in a dataframe:

# %%
attrs = [a for a in dir(rules[0]) if not a.startswith("_")]
attrs
# Out:
# ['confidence',
#  'conviction',
#  'count_full',
#  'count_lhs',
#  'count_rhs',
#  'lhs',
#  'lift',
#  'num_transactions',
#  'rhs',
#  'rpf',
#  'support']

# %%
rules_rec = []
for r in rules:
    rdict={}
    for a in attrs:
        rdict[a]=getattr(r,a)
        rdict["rule"]=str(r).split("} (")[0]+"}"
        rdict["len_l"]=len(r.lhs)
        rdict["len_r"]=len(r.rhs)
    rules_rec.append(rdict)

# %%
rules_df = pd.DataFrame(rules_rec)
rules_df.set_index('rule',inplace=True)
rules_df = rules_df[['len_l', 'len_r','count_lhs','count_rhs','support','confidence','lift','rpf','conviction','lhs','rhs']]

# %%
rules_df
# Out:
#                                                     len_l  len_r  count_lhs  \
# rule
# {('BedroomAbvGr', 3)} -> {('BldgType', '1Fam')}         1      1        804
# {('BedroomAbvGr', 4)} -> {('BldgType', '1Fam')}         1      1        213
# {('FullBath', 1)} -> {('BldgType', '1Fam')}             1      1        650
# {('GrLivArea', 'high')} -> {('BldgType', '1Fam')}       1      1        292
# {('GrLivArea', 'medium')} -> {('BldgType', '1Fa...      1      1        292
# ...                                                   ...    ...        ...
# {('BldgType', '1Fam'), ('SalePrice', 'very high...      4      2         78
# {('BldgType', '1Fam'), ('SalePrice', 'very high...      4      2         89
# {('BldgType', '1Fam'), ('OverallCond', 5), ('To...      4      2         86
# {('SalePrice', 'very high'), ('TotalBsmtSF', 'v...      3      3         83
# {('BldgType', '1Fam'), ('TotalBsmtSF', 'very hi...      3      3         91
#
#                                                     count_rhs   support  \
# rule
# {('BedroomAbvGr', 3)} -> {('BldgType', '1Fam')}          1220  0.514384
# {('BedroomAbvGr', 4)} -> {('BldgType', '1Fam')}          1220  0.123288
# {('FullBath', 1)} -> {('BldgType', '1Fam')}              1220  0.393836
# {('GrLivArea', 'high')} -> {('BldgType', '1Fam')}        1220  0.169178
# {('GrLivArea', 'medium')} -> {('BldgType', '1Fa...       1220  0.160274
# ...                                                       ...       ...
# {('BldgType', '1Fam'), ('SalePrice', 'very high...        271  0.050000
# {('BldgType', '1Fam'), ('SalePrice', 'very high...        186  0.050000
# {('BldgType', '1Fam'), ('OverallCond', 5), ('To...        134  0.050000
# {('SalePrice', 'very high'), ('TotalBsmtSF', 'v...        210  0.050000
# {('BldgType', '1Fam'), ('TotalBsmtSF', 'very hi...        131  0.050000
#
#                                                     confidence      lift  \
# rule
# {('BedroomAbvGr', 3)} -> {('BldgType', '1Fam')}       0.934080  1.117833
# {('BedroomAbvGr', 4)} -> {('BldgType', '1Fam')}       0.845070  1.011314
# {('FullBath', 1)} -> {('BldgType', '1Fam')}           0.884615  1.058638
# {('GrLivArea', 'high')} -> {('BldgType', '1Fam')}     0.845890  1.012295
# {('GrLivArea', 'medium')} -> {('BldgType', '1Fa...    0.801370  0.959016
# ...                                                        ...       ...
# {('BldgType', '1Fam'), ('SalePrice', 'very high...    0.935897  5.042104
# {('BldgType', '1Fam'), ('SalePrice', 'very high...    0.820225  6.438323
# {('BldgType', '1Fam'), ('OverallCond', 5), ('To...    0.848837  9.248525
# {('SalePrice', 'very high'), ('TotalBsmtSF', 'v...    0.879518  6.114745
# {('BldgType', '1Fam'), ('TotalBsmtSF', 'very hi...    0.802198  8.940525
#
#                                                          rpf  conviction  \
# rule
# {('BedroomAbvGr', 3)} -> {('BldgType', '1Fam')}     0.480475    2.493668
# {('BedroomAbvGr', 4)} -> {('BldgType', '1Fam')}     0.104187    1.061021
# {('FullBath', 1)} -> {('BldgType', '1Fam')}         0.348393    1.424658
# {('GrLivArea', 'high')} -> {('BldgType', '1Fam')}   0.143106    1.066667
# {('GrLivArea', 'medium')} -> {('BldgType', '1Fa...  0.128439    0.827586
# ...                                                      ...         ...
# {('BldgType', '1Fam'), ('SalePrice', 'very high...  0.046795   12.704383
# {('BldgType', '1Fam'), ('SalePrice', 'very high...  0.041011    4.853853
# {('BldgType', '1Fam'), ('OverallCond', 5), ('To...  0.042442    6.008219
# {('SalePrice', 'very high'), ('TotalBsmtSF', 'v...  0.043976    7.106164
# {('BldgType', '1Fam'), ('TotalBsmtSF', 'very hi...  0.040110    4.601941
#
#                                                                                                   lhs  \
# rule
# {('BedroomAbvGr', 3)} -> {('BldgType', '1Fam')}                                  ((BedroomAbvGr, 3),)
# {('BedroomAbvGr', 4)} -> {('BldgType', '1Fam')}                                  ((BedroomAbvGr, 4),)
# {('FullBath', 1)} -> {('BldgType', '1Fam')}                                          ((FullBath, 1),)
# {('GrLivArea', 'high')} -> {('BldgType', '1Fam')}                                ((GrLivArea, high),)
# {('GrLivArea', 'medium')} -> {('BldgType', '1Fa...                             ((GrLivArea, medium),)
# ...                                                                                               ...
# {('BldgType', '1Fam'), ('SalePrice', 'very high...  ((BldgType, 1Fam), (SalePrice, very high), (To...
# {('BldgType', '1Fam'), ('SalePrice', 'very high...  ((BldgType, 1Fam), (SalePrice, very high), (To...
# {('BldgType', '1Fam'), ('OverallCond', 5), ('To...  ((BldgType, 1Fam), (OverallCond, 5), (TotalBsm...
# {('SalePrice', 'very high'), ('TotalBsmtSF', 'v...  ((SalePrice, very high), (TotalBsmtSF, very hi...
# {('BldgType', '1Fam'), ('TotalBsmtSF', 'very hi...  ((BldgType, 1Fam), (TotalBsmtSF, very high), (...
#
#                                                                                                   rhs
# rule
# {('BedroomAbvGr', 3)} -> {('BldgType', '1Fam')}                                   ((BldgType, 1Fam),)
# {('BedroomAbvGr', 4)} -> {('BldgType', '1Fam')}                                   ((BldgType, 1Fam),)
# {('FullBath', 1)} -> {('BldgType', '1Fam')}                                       ((BldgType, 1Fam),)
# {('GrLivArea', 'high')} -> {('BldgType', '1Fam')}                                 ((BldgType, 1Fam),)
# {('GrLivArea', 'medium')} -> {('BldgType', '1Fa...                                ((BldgType, 1Fam),)
# ...                                                                                               ...
# {('BldgType', '1Fam'), ('SalePrice', 'very high...         ((OverallCond, 5), (YearBuilt, very high))
# {('BldgType', '1Fam'), ('SalePrice', 'very high...      ((OverallCond, 5), (YearRemodAdd, very high))
# {('BldgType', '1Fam'), ('OverallCond', 5), ('To...   ((SalePrice, very high), (YearBuilt, very high))
# {('SalePrice', 'very high'), ('TotalBsmtSF', 'v...  ((BldgType, 1Fam), (OverallCond, 5), (YearBuil...
# {('BldgType', '1Fam'), ('TotalBsmtSF', 'very hi...  ((OverallCond, 5), (SalePrice, very high), (Ye...
#
# [1787 rows x 11 columns]

# %% [markdown]
# ##### We can filter rules with high/very high sale price:

# %%
def is_in_itemset(itemset, key,value):
    if type(value) is not list:
        value = [value]
    for (k,v) in itemset:
            if k ==key and v in value:
                return True
    return False

# %%
filter_rhs = rules_df.rhs.apply(lambda x: is_in_itemset(x,'SalePrice',['high','very high']))

# %%
rules_df[filter_rhs].sort_values(['len_r','support'],ascending=[True,False])
# Out:
#                                                     len_l  len_r  count_lhs  \
# rule
# {('BldgType', '1Fam'), ('OverallQual', 8)} -> {...      2      1        142
# {('BldgType', '1Fam'), ('FullBath', 2), ('Overa...      3      1        128
# {('BldgType', '1Fam'), ('OverallCond', 5), ('Ov...      3      1        122
# {('TotalBsmtSF', 'very high'), ('YearBuilt', 'v...      2      1        120
# {('BldgType', '1Fam'), ('FullBath', 2), ('Overa...      4      1        114
# {('OverallCond', 5), ('TotalBsmtSF', 'very high...      3      1        117
# {('BldgType', '1Fam'), ('TotalBsmtSF', 'very hi...      3      1        110
# {('FullBath', 2), ('TotalBsmtSF', 'very high'),...      3      1        109
# {('BldgType', '1Fam'), ('OverallCond', 5), ('To...      4      1        107
# {('FullBath', 2), ('OverallCond', 5), ('TotalBs...      4      1        107
# {('OverallQual', 8), ('TotalBsmtSF', 'very high...      2      1         92
# {('TotalBsmtSF', 'very high'), ('YearRemodAdd',...      2      1         97
# {('TotalBsmtSF', 'very high'), ('YearBuilt', 'v...      3      1         95
# {('BldgType', '1Fam'), ('FullBath', 2), ('GrLiv...      4      1        101
# {('GrLivArea', 'very high'), ('TotalBsmtSF', 'v...      2      1         91
# {('BldgType', '1Fam'), ('GrLivArea', 'very high...      3      1         89
# {('BldgType', '1Fam'), ('FullBath', 2), ('Total...      4      1        100
# {('BldgType', '1Fam'), ('TotalBsmtSF', 'very hi...      3      1         91
# {('GrLivArea', 'very high'), ('LotFrontage', 'v...      3      1         92
# {('OverallCond', 5), ('TotalBsmtSF', 'very high...      3      1         92
# {('BldgType', '1Fam'), ('GrLivArea', 'very high...      4      1         88
# {('OverallCond', 5), ('TotalBsmtSF', 'very high...      4      1         92
# {('OverallCond', 5), ('OverallQual', 8), ('Tota...      3      1         84
# {('LotFrontage', 'very high'), ('OverallCond', ...      3      1         95
# {('BldgType', '1Fam'), ('LotFrontage', 'very hi...      4      1         92
# {('BldgType', '1Fam'), ('TotalBsmtSF', 'very hi...      4      1         89
# {('GrLivArea', 'very high'), ('OverallQual', 8)...      2      1         80
# {('BldgType', '1Fam'), ('GrLivArea', 'very high...      3      1         80
# {('BldgType', '1Fam'), ('OverallQual', 8), ('To...      3      1         79
# {('FullBath', 2), ('OverallQual', 8), ('TotalBs...      3      1         80
# {('FullBath', 2), ('TotalBsmtSF', 'very high'),...      3      1         86
# {('BldgType', '1Fam'), ('OverallCond', 5), ('To...      4      1         86
# {('BldgType', '1Fam'), ('OverallCond', 5), ('To...      5      1         86
# {('TotalBsmtSF', 'very high'), ('YearRemodAdd',...      2      2         97
# {('GrLivArea', 'very high'), ('TotalBsmtSF', 'v...      2      2         91
# {('TotalBsmtSF', 'very high'), ('YearRemodAdd',...      2      2         97
# {('TotalBsmtSF', 'very high'), ('YearRemodAdd',...      2      2         97
# {('GrLivArea', 'very high'), ('LotFrontage', 'v...      3      2         92
# {('TotalBsmtSF', 'very high'), ('YearBuilt', 'v...      3      2         95
# {('OverallCond', 5), ('TotalBsmtSF', 'very high...      3      2         92
# {('OverallQual', 8), ('TotalBsmtSF', 'very high...      2      2         92
# {('LotFrontage', 'very high'), ('OverallCond', ...      3      2         95
# {('TotalBsmtSF', 'very high'), ('YearBuilt', 'v...      3      2         95
# {('BldgType', '1Fam'), ('TotalBsmtSF', 'very hi...      3      2         91
# {('GrLivArea', 'very high'), ('OverallQual', 8)...      2      2         80
# {('BldgType', '1Fam'), ('TotalBsmtSF', 'very hi...      3      2         91
# {('BldgType', '1Fam'), ('TotalBsmtSF', 'very hi...      4      2         89
# {('BldgType', '1Fam'), ('OverallCond', 5), ('To...      4      2         86
# {('TotalBsmtSF', 'very high'), ('YearRemodAdd',...      2      3         97
# {('BldgType', '1Fam'), ('TotalBsmtSF', 'very hi...      3      3         91
#
#                                                     count_rhs   support  \
# rule
# {('BldgType', '1Fam'), ('OverallQual', 8)} -> {...        289  0.080822
# {('BldgType', '1Fam'), ('FullBath', 2), ('Overa...        289  0.073288
# {('BldgType', '1Fam'), ('OverallCond', 5), ('Ov...        289  0.071233
# {('TotalBsmtSF', 'very high'), ('YearBuilt', 'v...        289  0.067123
# {('BldgType', '1Fam'), ('FullBath', 2), ('Overa...        289  0.065753
# {('OverallCond', 5), ('TotalBsmtSF', 'very high...        289  0.065068
# {('BldgType', '1Fam'), ('TotalBsmtSF', 'very hi...        289  0.060959
# {('FullBath', 2), ('TotalBsmtSF', 'very high'),...        289  0.060274
# {('BldgType', '1Fam'), ('OverallCond', 5), ('To...        289  0.058904
# {('FullBath', 2), ('OverallCond', 5), ('TotalBs...        289  0.058904
# {('OverallQual', 8), ('TotalBsmtSF', 'very high...        289  0.057534
# {('TotalBsmtSF', 'very high'), ('YearRemodAdd',...        289  0.056849
# {('TotalBsmtSF', 'very high'), ('YearBuilt', 'v...        289  0.055479
# {('BldgType', '1Fam'), ('FullBath', 2), ('GrLiv...        289  0.055479
# {('GrLivArea', 'very high'), ('TotalBsmtSF', 'v...        289  0.054795
# {('BldgType', '1Fam'), ('GrLivArea', 'very high...        289  0.054795
# {('BldgType', '1Fam'), ('FullBath', 2), ('Total...        289  0.054795
# {('BldgType', '1Fam'), ('TotalBsmtSF', 'very hi...        289  0.053425
# {('GrLivArea', 'very high'), ('LotFrontage', 'v...        289  0.053425
# {('OverallCond', 5), ('TotalBsmtSF', 'very high...        289  0.053425
# {('BldgType', '1Fam'), ('GrLivArea', 'very high...        289  0.053425
# {('OverallCond', 5), ('TotalBsmtSF', 'very high...        289  0.053425
# {('OverallCond', 5), ('OverallQual', 8), ('Tota...        289  0.052740
# {('LotFrontage', 'very high'), ('OverallCond', ...        289  0.052055
# {('BldgType', '1Fam'), ('LotFrontage', 'very hi...        289  0.052055
# {('BldgType', '1Fam'), ('TotalBsmtSF', 'very hi...        289  0.052055
# {('GrLivArea', 'very high'), ('OverallQual', 8)...        289  0.051370
# {('BldgType', '1Fam'), ('GrLivArea', 'very high...        289  0.051370
# {('BldgType', '1Fam'), ('OverallQual', 8), ('To...        289  0.050000
# {('FullBath', 2), ('OverallQual', 8), ('TotalBs...        289  0.050000
# {('FullBath', 2), ('TotalBsmtSF', 'very high'),...        289  0.050000
# {('BldgType', '1Fam'), ('OverallCond', 5), ('To...        289  0.050000
# {('BldgType', '1Fam'), ('OverallCond', 5), ('To...        289  0.050000
# {('TotalBsmtSF', 'very high'), ('YearRemodAdd',...        134  0.055479
# {('GrLivArea', 'very high'), ('TotalBsmtSF', 'v...        267  0.054795
# {('TotalBsmtSF', 'very high'), ('YearRemodAdd',...        267  0.053425
# {('TotalBsmtSF', 'very high'), ('YearRemodAdd',...        231  0.053425
# {('GrLivArea', 'very high'), ('LotFrontage', 'v...        267  0.053425
# {('TotalBsmtSF', 'very high'), ('YearBuilt', 'v...        231  0.053425
# {('OverallCond', 5), ('TotalBsmtSF', 'very high...        134  0.053425
# {('OverallQual', 8), ('TotalBsmtSF', 'very high...        231  0.052740
# {('LotFrontage', 'very high'), ('OverallCond', ...        267  0.052055
# {('TotalBsmtSF', 'very high'), ('YearBuilt', 'v...        267  0.052055
# {('BldgType', '1Fam'), ('TotalBsmtSF', 'very hi...        134  0.052055
# {('GrLivArea', 'very high'), ('OverallQual', 8)...        267  0.051370
# {('BldgType', '1Fam'), ('TotalBsmtSF', 'very hi...        231  0.050000
# {('BldgType', '1Fam'), ('TotalBsmtSF', 'very hi...        231  0.050000
# {('BldgType', '1Fam'), ('OverallCond', 5), ('To...        134  0.050000
# {('TotalBsmtSF', 'very high'), ('YearRemodAdd',...        131  0.053425
# {('BldgType', '1Fam'), ('TotalBsmtSF', 'very hi...        131  0.050000
#
#                                                     confidence      lift  \
# rule
# {('BldgType', '1Fam'), ('OverallQual', 8)} -> {...    0.830986  4.198060
# {('BldgType', '1Fam'), ('FullBath', 2), ('Overa...    0.835938  4.223075
# {('BldgType', '1Fam'), ('OverallCond', 5), ('Ov...    0.852459  4.306540
# {('TotalBsmtSF', 'very high'), ('YearBuilt', 'v...    0.816667  4.125721
# {('BldgType', '1Fam'), ('FullBath', 2), ('Overa...    0.842105  4.254234
# {('OverallCond', 5), ('TotalBsmtSF', 'very high...    0.811966  4.101973
# {('BldgType', '1Fam'), ('TotalBsmtSF', 'very hi...    0.809091  4.087449
# {('FullBath', 2), ('TotalBsmtSF', 'very high'),...    0.807339  4.078601
# {('BldgType', '1Fam'), ('OverallCond', 5), ('To...    0.803738  4.060408
# {('FullBath', 2), ('OverallCond', 5), ('TotalBs...    0.803738  4.060408
# {('OverallQual', 8), ('TotalBsmtSF', 'very high...    0.913043  4.612607
# {('TotalBsmtSF', 'very high'), ('YearRemodAdd',...    0.855670  4.322762
# {('TotalBsmtSF', 'very high'), ('YearBuilt', 'v...    0.852632  4.307412
# {('BldgType', '1Fam'), ('FullBath', 2), ('GrLiv...    0.801980  4.051526
# {('GrLivArea', 'very high'), ('TotalBsmtSF', 'v...    0.879121  4.441234
# {('BldgType', '1Fam'), ('GrLivArea', 'very high...    0.898876  4.541037
# {('BldgType', '1Fam'), ('FullBath', 2), ('Total...    0.800000  4.041522
# {('BldgType', '1Fam'), ('TotalBsmtSF', 'very hi...    0.857143  4.330203
# {('GrLivArea', 'very high'), ('LotFrontage', 'v...    0.847826  4.283135
# {('OverallCond', 5), ('TotalBsmtSF', 'very high...    0.847826  4.283135
# {('BldgType', '1Fam'), ('GrLivArea', 'very high...    0.886364  4.477823
# {('OverallCond', 5), ('TotalBsmtSF', 'very high...    0.847826  4.283135
# {('OverallCond', 5), ('OverallQual', 8), ('Tota...    0.916667  4.630911
# {('LotFrontage', 'very high'), ('OverallCond', ...    0.800000  4.041522
# {('BldgType', '1Fam'), ('LotFrontage', 'very hi...    0.826087  4.173311
# {('BldgType', '1Fam'), ('TotalBsmtSF', 'very hi...    0.853933  4.313985
# {('GrLivArea', 'very high'), ('OverallQual', 8)...    0.937500  4.736159
# {('BldgType', '1Fam'), ('GrLivArea', 'very high...    0.937500  4.736159
# {('BldgType', '1Fam'), ('OverallQual', 8), ('To...    0.924051  4.668214
# {('FullBath', 2), ('OverallQual', 8), ('TotalBs...    0.912500  4.609862
# {('FullBath', 2), ('TotalBsmtSF', 'very high'),...    0.848837  4.288243
# {('BldgType', '1Fam'), ('OverallCond', 5), ('To...    0.848837  4.288243
# {('BldgType', '1Fam'), ('OverallCond', 5), ('To...    0.848837  4.288243
# {('TotalBsmtSF', 'very high'), ('YearRemodAdd',...    0.835052  9.098323
# {('GrLivArea', 'very high'), ('TotalBsmtSF', 'v...    0.879121  4.807178
# {('TotalBsmtSF', 'very high'), ('YearRemodAdd',...    0.804124  4.397081
# {('TotalBsmtSF', 'very high'), ('YearRemodAdd',...    0.804124  5.082340
# {('GrLivArea', 'very high'), ('LotFrontage', 'v...    0.847826  4.636053
# {('TotalBsmtSF', 'very high'), ('YearBuilt', 'v...    0.821053  5.189337
# {('OverallCond', 5), ('TotalBsmtSF', 'very high...    0.847826  9.237508
# {('OverallQual', 8), ('TotalBsmtSF', 'very high...    0.836957  5.289855
# {('LotFrontage', 'very high'), ('OverallCond', ...    0.800000  4.374532
# {('TotalBsmtSF', 'very high'), ('YearBuilt', 'v...    0.800000  4.374532
# {('BldgType', '1Fam'), ('TotalBsmtSF', 'very hi...    0.835165  9.099557
# {('GrLivArea', 'very high'), ('OverallQual', 8)...    0.937500  5.126404
# {('BldgType', '1Fam'), ('TotalBsmtSF', 'very hi...    0.802198  5.070168
# {('BldgType', '1Fam'), ('TotalBsmtSF', 'very hi...    0.820225  5.184104
# {('BldgType', '1Fam'), ('OverallCond', 5), ('To...    0.848837  9.248525
# {('TotalBsmtSF', 'very high'), ('YearRemodAdd',...    0.804124  8.961989
# {('BldgType', '1Fam'), ('TotalBsmtSF', 'very hi...    0.802198  8.940525
#
#                                                          rpf  conviction  \
# rule
# {('BldgType', '1Fam'), ('OverallQual', 8)} -> {...  0.067162    4.745491
# {('BldgType', '1Fam'), ('FullBath', 2), ('Overa...  0.061264    4.888715
# {('BldgType', '1Fam'), ('OverallCond', 5), ('Ov...  0.060723    5.436149
# {('TotalBsmtSF', 'very high'), ('YearBuilt', 'v...  0.054817    4.374844
# {('BldgType', '1Fam'), ('FullBath', 2), ('Overa...  0.055371    5.079680
# {('OverallCond', 5), ('TotalBsmtSF', 'very high...  0.052833    4.265473
# {('BldgType', '1Fam'), ('TotalBsmtSF', 'very hi...  0.049321    4.201239
# {('FullBath', 2), ('TotalBsmtSF', 'very high'),...  0.048662    4.163046
# {('BldgType', '1Fam'), ('OverallCond', 5), ('To...  0.047343    4.086660
# {('FullBath', 2), ('OverallCond', 5), ('TotalBs...  0.047343    4.086660
# {('OverallQual', 8), ('TotalBsmtSF', 'very high...  0.052531    9.223630
# {('TotalBsmtSF', 'very high'), ('YearRemodAdd',...  0.048644    5.557094
# {('TotalBsmtSF', 'very high'), ('YearBuilt', 'v...  0.047304    5.442515
# {('BldgType', '1Fam'), ('FullBath', 2), ('GrLiv...  0.044493    4.050377
# {('GrLivArea', 'very high'), ('TotalBsmtSF', 'v...  0.048171    6.635181
# {('BldgType', '1Fam'), ('GrLivArea', 'very high...  0.049254    7.931431
# {('BldgType', '1Fam'), ('FullBath', 2), ('Total...  0.043836    4.010274
# {('BldgType', '1Fam'), ('TotalBsmtSF', 'very hi...  0.045793    5.614384
# {('GrLivArea', 'very high'), ('LotFrontage', 'v...  0.045295    5.270646
# {('OverallCond', 5), ('TotalBsmtSF', 'very high...  0.045295    5.270646
# {('BldgType', '1Fam'), ('GrLivArea', 'very high...  0.047354    7.058082
# {('OverallCond', 5), ('TotalBsmtSF', 'very high...  0.045295    5.270646
# {('OverallCond', 5), ('OverallQual', 8), ('Tota...  0.048345    9.624657
# {('LotFrontage', 'very high'), ('OverallCond', ...  0.041644    4.010274
# {('BldgType', '1Fam'), ('LotFrontage', 'very hi...  0.043002    4.611815
# {('BldgType', '1Fam'), ('TotalBsmtSF', 'very hi...  0.044451    5.490990
# {('GrLivArea', 'very high'), ('OverallQual', 8)...  0.048159   12.832877
# {('BldgType', '1Fam'), ('GrLivArea', 'very high...  0.048159   12.832877
# {('BldgType', '1Fam'), ('OverallQual', 8), ('To...  0.046203   10.560388
# {('FullBath', 2), ('OverallQual', 8), ('TotalBs...  0.045625    9.166340
# {('FullBath', 2), ('TotalBsmtSF', 'very high'),...  0.042442    5.305901
# {('BldgType', '1Fam'), ('OverallCond', 5), ('To...  0.042442    5.305901
# {('BldgType', '1Fam'), ('OverallCond', 5), ('To...  0.042442    5.305901
# {('TotalBsmtSF', 'very high'), ('YearRemodAdd',...  0.046328    5.506079
# {('GrLivArea', 'very high'), ('TotalBsmtSF', 'v...  0.048171    6.759838
# {('TotalBsmtSF', 'very high'), ('YearRemodAdd',...  0.042960    4.171629
# {('TotalBsmtSF', 'very high'), ('YearRemodAdd',...  0.042960    4.297513
# {('GrLivArea', 'very high'), ('LotFrontage', 'v...  0.045295    5.369667
# {('TotalBsmtSF', 'very high'), ('YearBuilt', 'v...  0.043864    4.704069
# {('OverallCond', 5), ('TotalBsmtSF', 'very high...  0.045295    5.968297
# {('OverallQual', 8), ('TotalBsmtSF', 'very high...  0.044141    5.162922
# {('LotFrontage', 'very high'), ('OverallCond', ...  0.041644    4.085616
# {('TotalBsmtSF', 'very high'), ('YearBuilt', 'v...  0.041644    4.085616
# {('BldgType', '1Fam'), ('TotalBsmtSF', 'very hi...  0.043474    5.509863
# {('GrLivArea', 'very high'), ('OverallQual', 8)...  0.048159   13.073972
# {('BldgType', '1Fam'), ('TotalBsmtSF', 'very hi...  0.040110    4.255670
# {('BldgType', '1Fam'), ('TotalBsmtSF', 'very hi...  0.041011    4.682406
# {('BldgType', '1Fam'), ('OverallCond', 5), ('To...  0.042442    6.008219
# {('TotalBsmtSF', 'very high'), ('YearRemodAdd',...  0.042960    4.647188
# {('BldgType', '1Fam'), ('TotalBsmtSF', 'very hi...  0.040110    4.601941
#
#                                                                                                   lhs  \
# rule
# {('BldgType', '1Fam'), ('OverallQual', 8)} -> {...               ((BldgType, 1Fam), (OverallQual, 8))
# {('BldgType', '1Fam'), ('FullBath', 2), ('Overa...  ((BldgType, 1Fam), (FullBath, 2), (OverallQual...
# {('BldgType', '1Fam'), ('OverallCond', 5), ('Ov...  ((BldgType, 1Fam), (OverallCond, 5), (OverallQ...
# {('TotalBsmtSF', 'very high'), ('YearBuilt', 'v...  ((TotalBsmtSF, very high), (YearBuilt, very hi...
# {('BldgType', '1Fam'), ('FullBath', 2), ('Overa...  ((BldgType, 1Fam), (FullBath, 2), (OverallCond...
# {('OverallCond', 5), ('TotalBsmtSF', 'very high...  ((OverallCond, 5), (TotalBsmtSF, very high), (...
# {('BldgType', '1Fam'), ('TotalBsmtSF', 'very hi...  ((BldgType, 1Fam), (TotalBsmtSF, very high), (...
# {('FullBath', 2), ('TotalBsmtSF', 'very high'),...  ((FullBath, 2), (TotalBsmtSF, very high), (Yea...
# {('BldgType', '1Fam'), ('OverallCond', 5), ('To...  ((BldgType, 1Fam), (OverallCond, 5), (TotalBsm...
# {('FullBath', 2), ('OverallCond', 5), ('TotalBs...  ((FullBath, 2), (OverallCond, 5), (TotalBsmtSF...
# {('OverallQual', 8), ('TotalBsmtSF', 'very high...       ((OverallQual, 8), (TotalBsmtSF, very high))
# {('TotalBsmtSF', 'very high'), ('YearRemodAdd',...  ((TotalBsmtSF, very high), (YearRemodAdd, very...
# {('TotalBsmtSF', 'very high'), ('YearBuilt', 'v...  ((TotalBsmtSF, very high), (YearBuilt, very hi...
# {('BldgType', '1Fam'), ('FullBath', 2), ('GrLiv...  ((BldgType, 1Fam), (FullBath, 2), (GrLivArea, ...
# {('GrLivArea', 'very high'), ('TotalBsmtSF', 'v...  ((GrLivArea, very high), (TotalBsmtSF, very hi...
# {('BldgType', '1Fam'), ('GrLivArea', 'very high...  ((BldgType, 1Fam), (GrLivArea, very high), (To...
# {('BldgType', '1Fam'), ('FullBath', 2), ('Total...  ((BldgType, 1Fam), (FullBath, 2), (TotalBsmtSF...
# {('BldgType', '1Fam'), ('TotalBsmtSF', 'very hi...  ((BldgType, 1Fam), (TotalBsmtSF, very high), (...
# {('GrLivArea', 'very high'), ('LotFrontage', 'v...  ((GrLivArea, very high), (LotFrontage, very hi...
# {('OverallCond', 5), ('TotalBsmtSF', 'very high...  ((OverallCond, 5), (TotalBsmtSF, very high), (...
# {('BldgType', '1Fam'), ('GrLivArea', 'very high...  ((BldgType, 1Fam), (GrLivArea, very high), (Lo...
# {('OverallCond', 5), ('TotalBsmtSF', 'very high...  ((OverallCond, 5), (TotalBsmtSF, very high), (...
# {('OverallCond', 5), ('OverallQual', 8), ('Tota...  ((OverallCond, 5), (OverallQual, 8), (TotalBsm...
# {('LotFrontage', 'very high'), ('OverallCond', ...  ((LotFrontage, very high), (OverallCond, 5), (...
# {('BldgType', '1Fam'), ('LotFrontage', 'very hi...  ((BldgType, 1Fam), (LotFrontage, very high), (...
# {('BldgType', '1Fam'), ('TotalBsmtSF', 'very hi...  ((BldgType, 1Fam), (TotalBsmtSF, very high), (...
# {('GrLivArea', 'very high'), ('OverallQual', 8)...         ((GrLivArea, very high), (OverallQual, 8))
# {('BldgType', '1Fam'), ('GrLivArea', 'very high...  ((BldgType, 1Fam), (GrLivArea, very high), (Ov...
# {('BldgType', '1Fam'), ('OverallQual', 8), ('To...  ((BldgType, 1Fam), (OverallQual, 8), (TotalBsm...
# {('FullBath', 2), ('OverallQual', 8), ('TotalBs...  ((FullBath, 2), (OverallQual, 8), (TotalBsmtSF...
# {('FullBath', 2), ('TotalBsmtSF', 'very high'),...  ((FullBath, 2), (TotalBsmtSF, very high), (Yea...
# {('BldgType', '1Fam'), ('OverallCond', 5), ('To...  ((BldgType, 1Fam), (OverallCond, 5), (TotalBsm...
# {('BldgType', '1Fam'), ('OverallCond', 5), ('To...  ((BldgType, 1Fam), (OverallCond, 5), (TotalBsm...
# {('TotalBsmtSF', 'very high'), ('YearRemodAdd',...  ((TotalBsmtSF, very high), (YearRemodAdd, very...
# {('GrLivArea', 'very high'), ('TotalBsmtSF', 'v...  ((GrLivArea, very high), (TotalBsmtSF, very hi...
# {('TotalBsmtSF', 'very high'), ('YearRemodAdd',...  ((TotalBsmtSF, very high), (YearRemodAdd, very...
# {('TotalBsmtSF', 'very high'), ('YearRemodAdd',...  ((TotalBsmtSF, very high), (YearRemodAdd, very...
# {('GrLivArea', 'very high'), ('LotFrontage', 'v...  ((GrLivArea, very high), (LotFrontage, very hi...
# {('TotalBsmtSF', 'very high'), ('YearBuilt', 'v...  ((TotalBsmtSF, very high), (YearBuilt, very hi...
# {('OverallCond', 5), ('TotalBsmtSF', 'very high...  ((OverallCond, 5), (TotalBsmtSF, very high), (...
# {('OverallQual', 8), ('TotalBsmtSF', 'very high...       ((OverallQual, 8), (TotalBsmtSF, very high))
# {('LotFrontage', 'very high'), ('OverallCond', ...  ((LotFrontage, very high), (OverallCond, 5), (...
# {('TotalBsmtSF', 'very high'), ('YearBuilt', 'v...  ((TotalBsmtSF, very high), (YearBuilt, very hi...
# {('BldgType', '1Fam'), ('TotalBsmtSF', 'very hi...  ((BldgType, 1Fam), (TotalBsmtSF, very high), (...
# {('GrLivArea', 'very high'), ('OverallQual', 8)...         ((GrLivArea, very high), (OverallQual, 8))
# {('BldgType', '1Fam'), ('TotalBsmtSF', 'very hi...  ((BldgType, 1Fam), (TotalBsmtSF, very high), (...
# {('BldgType', '1Fam'), ('TotalBsmtSF', 'very hi...  ((BldgType, 1Fam), (TotalBsmtSF, very high), (...
# {('BldgType', '1Fam'), ('OverallCond', 5), ('To...  ((BldgType, 1Fam), (OverallCond, 5), (TotalBsm...
# {('TotalBsmtSF', 'very high'), ('YearRemodAdd',...  ((TotalBsmtSF, very high), (YearRemodAdd, very...
# {('BldgType', '1Fam'), ('TotalBsmtSF', 'very hi...  ((BldgType, 1Fam), (TotalBsmtSF, very high), (...
#
#                                                                                                   rhs
# rule
# {('BldgType', '1Fam'), ('OverallQual', 8)} -> {...                          ((SalePrice, very high),)
# {('BldgType', '1Fam'), ('FullBath', 2), ('Overa...                          ((SalePrice, very high),)
# {('BldgType', '1Fam'), ('OverallCond', 5), ('Ov...                          ((SalePrice, very high),)
# {('TotalBsmtSF', 'very high'), ('YearBuilt', 'v...                          ((SalePrice, very high),)
# {('BldgType', '1Fam'), ('FullBath', 2), ('Overa...                          ((SalePrice, very high),)
# {('OverallCond', 5), ('TotalBsmtSF', 'very high...                          ((SalePrice, very high),)
# {('BldgType', '1Fam'), ('TotalBsmtSF', 'very hi...                          ((SalePrice, very high),)
# {('FullBath', 2), ('TotalBsmtSF', 'very high'),...                          ((SalePrice, very high),)
# {('BldgType', '1Fam'), ('OverallCond', 5), ('To...                          ((SalePrice, very high),)
# {('FullBath', 2), ('OverallCond', 5), ('TotalBs...                          ((SalePrice, very high),)
# {('OverallQual', 8), ('TotalBsmtSF', 'very high...                          ((SalePrice, very high),)
# {('TotalBsmtSF', 'very high'), ('YearRemodAdd',...                          ((SalePrice, very high),)
# {('TotalBsmtSF', 'very high'), ('YearBuilt', 'v...                          ((SalePrice, very high),)
# {('BldgType', '1Fam'), ('FullBath', 2), ('GrLiv...                          ((SalePrice, very high),)
# {('GrLivArea', 'very high'), ('TotalBsmtSF', 'v...                          ((SalePrice, very high),)
# {('BldgType', '1Fam'), ('GrLivArea', 'very high...                          ((SalePrice, very high),)
# {('BldgType', '1Fam'), ('FullBath', 2), ('Total...                          ((SalePrice, very high),)
# {('BldgType', '1Fam'), ('TotalBsmtSF', 'very hi...                          ((SalePrice, very high),)
# {('GrLivArea', 'very high'), ('LotFrontage', 'v...                          ((SalePrice, very high),)
# {('OverallCond', 5), ('TotalBsmtSF', 'very high...                          ((SalePrice, very high),)
# {('BldgType', '1Fam'), ('GrLivArea', 'very high...                          ((SalePrice, very high),)
# {('OverallCond', 5), ('TotalBsmtSF', 'very high...                          ((SalePrice, very high),)
# {('OverallCond', 5), ('OverallQual', 8), ('Tota...                          ((SalePrice, very high),)
# {('LotFrontage', 'very high'), ('OverallCond', ...                          ((SalePrice, very high),)
# {('BldgType', '1Fam'), ('LotFrontage', 'very hi...                          ((SalePrice, very high),)
# {('BldgType', '1Fam'), ('TotalBsmtSF', 'very hi...                          ((SalePrice, very high),)
# {('GrLivArea', 'very high'), ('OverallQual', 8)...                          ((SalePrice, very high),)
# {('BldgType', '1Fam'), ('GrLivArea', 'very high...                          ((SalePrice, very high),)
# {('BldgType', '1Fam'), ('OverallQual', 8), ('To...                          ((SalePrice, very high),)
# {('FullBath', 2), ('OverallQual', 8), ('TotalBs...                          ((SalePrice, very high),)
# {('FullBath', 2), ('TotalBsmtSF', 'very high'),...                          ((SalePrice, very high),)
# {('BldgType', '1Fam'), ('OverallCond', 5), ('To...                          ((SalePrice, very high),)
# {('BldgType', '1Fam'), ('OverallCond', 5), ('To...                          ((SalePrice, very high),)
# {('TotalBsmtSF', 'very high'), ('YearRemodAdd',...   ((SalePrice, very high), (YearBuilt, very high))
# {('GrLivArea', 'very high'), ('TotalBsmtSF', 'v...         ((BldgType, 1Fam), (SalePrice, very high))
# {('TotalBsmtSF', 'very high'), ('YearRemodAdd',...         ((BldgType, 1Fam), (SalePrice, very high))
# {('TotalBsmtSF', 'very high'), ('YearRemodAdd',...         ((OverallCond, 5), (SalePrice, very high))
# {('GrLivArea', 'very high'), ('LotFrontage', 'v...         ((BldgType, 1Fam), (SalePrice, very high))
# {('TotalBsmtSF', 'very high'), ('YearBuilt', 'v...         ((OverallCond, 5), (SalePrice, very high))
# {('OverallCond', 5), ('TotalBsmtSF', 'very high...   ((SalePrice, very high), (YearBuilt, very high))
# {('OverallQual', 8), ('TotalBsmtSF', 'very high...         ((OverallCond, 5), (SalePrice, very high))
# {('LotFrontage', 'very high'), ('OverallCond', ...         ((BldgType, 1Fam), (SalePrice, very high))
# {('TotalBsmtSF', 'very high'), ('YearBuilt', 'v...         ((BldgType, 1Fam), (SalePrice, very high))
# {('BldgType', '1Fam'), ('TotalBsmtSF', 'very hi...   ((SalePrice, very high), (YearBuilt, very high))
# {('GrLivArea', 'very high'), ('OverallQual', 8)...         ((BldgType, 1Fam), (SalePrice, very high))
# {('BldgType', '1Fam'), ('TotalBsmtSF', 'very hi...         ((OverallCond, 5), (SalePrice, very high))
# {('BldgType', '1Fam'), ('TotalBsmtSF', 'very hi...         ((OverallCond, 5), (SalePrice, very high))
# {('BldgType', '1Fam'), ('OverallCond', 5), ('To...   ((SalePrice, very high), (YearBuilt, very high))
# {('TotalBsmtSF', 'very high'), ('YearRemodAdd',...  ((OverallCond, 5), (SalePrice, very high), (Ye...
# {('BldgType', '1Fam'), ('TotalBsmtSF', 'very hi...  ((OverallCond, 5), (SalePrice, very high), (Ye...
